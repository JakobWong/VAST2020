# %%
import os

root_dir = 'MC2-Image-Data'

res_list = {}

for root, dirs, files in os.walk(root_dir):
    for file in files:
        if file.endswith('.txt'):
            
            # Open a file: file
            txt_file = open(os.path.join(root,file),mode='r','cp1252')

            # read all lines at once
            all_of_it = txt_file.read()
            
            # close the file
            txt_file.close()
            
            filecode = file.replace('caption.txt','')
            res_list[filecode] = os.path.join(root,all_of_it)
#             res_list.append(os.path.join(root,file))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2133ef45ea0f> in <module>
#      13
#      14             # read all lines at once
# ---> 15             all_of_it = txt_file.read(encoding='cp1252')
#      16
#      17             # close the file
#
# TypeError: read() takes no keyword arguments

# %%
res_list
# Out:
# ['MC2-Image-Data/Person33/Person33_42caption.txt',
#  'MC2-Image-Data/Person33/Person33_17caption.txt',
#  'MC2-Image-Data/Person33/Person33_31caption.txt',
#  'MC2-Image-Data/Person33/Person33_53caption.txt',
#  'MC2-Image-Data/Person33/Person33_1caption.txt',
#  'MC2-Image-Data/Person33/Person33_34caption.txt',
#  'MC2-Image-Data/Person33/Person33_61caption.txt',
#  'MC2-Image-Data/Person33/Person33_56caption.txt',
#  'MC2-Image-Data/Person33/Person33_4caption.txt',
#  'MC2-Image-Data/Person33/Person33_39caption.txt',
#  'MC2-Image-Data/Person33/Person33_47caption.txt',
#  'MC2-Image-Data/Person33/Person33_9caption.txt',
#  'MC2-Image-Data/Person33/Person33_12caption.txt',
#  'MC2-Image-Data/Person33/Person33_40caption.txt',
#  'MC2-Image-Data/Person33/Person33_15caption.txt',
#  'MC2-Image-Data/Person33/Person33_3caption.txt',
#  'MC2-Image-Data/Person33/Person33_33caption.txt',
#  'MC2-Image-Data/Person33/Person33_51caption.txt',
# ...
